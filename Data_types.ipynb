# %% [markdown]
# <a href="https://colab.research.google.com/github/purna-2007/Python/blob/main/Data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=("apple,grapes,mango")
print(x)
type(x)
# Out:
# apple,grapes,mango
# str

# %%
x=int(input("enter a number"))
print(x)
type(x)
# Out:
# enter a number45
# 45
# int

# %%
x=float(input("enter a number"))
print(x)
type(x)
# Out:
# enter a number456
# 456.0
# float

# %%
x=["apple","rani","devi"]
print(x)
type(x)
# Out:
# ['apple', 'rani', 'devi']
# list

# %%
x={"name":"purna","age":18}
print(x)
print(x.keys())
print(x.items())
type(x)
# Out:
# {'name': 'purna', 'age': 18}
# dict_keys(['name', 'age'])
# dict_items([('name', 'purna'), ('age', 18)])
# dict

# %%
x=range(56)
print(x)
type(x)
# Out:
# range(0, 56)
# range

# %%
x=("apple","mango")
print(x)
type(x)
# Out:
# ('apple', 'mango')
# tuple

# %%
x={"apple","cherry","grapes","apple"}
print(x)
type(x)
# Out:
# {'cherry', 'grapes', 'apple'}
# set
